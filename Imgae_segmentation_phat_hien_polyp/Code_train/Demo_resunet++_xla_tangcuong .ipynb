# %%
#import cac thu vieb can thiet
from tensorflow import keras
from tensorflow.keras import layers
import os
import numpy as np
import cv2
from glob import glob
from sklearn import model_selection
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger, TensorBoard
from tensorflow.keras.metrics import Precision, Recall, MeanIoU
import matplotlib.pyplot as plt
from tensorflow.keras.utils import CustomObjectScope
from tqdm import tqdm
from tensorflow.keras.optimizers import Adam, Nadam, SGD

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/'My Drive'/xla
# Out:
# /content/drive/My Drive/xla

# %%
#parameter
size_unet=256
#Lua chon cac sieu tham so Hyperparameters
batch=8
lr = 1e-4
epochs = 40

# %%
#Ham tra ve tap train, tap valid va tap test
def load_data():
    #Tach tap du lieu thanh 80% cho train, 10% cho val, 10% cho test
    split=0.1;
    images = sorted(glob( "images/*"))
    masks = sorted(glob("masks/*"))
    #glob giup hoan thien cac duong dan

    total_size = len(images)
    valid_size = int(split * total_size)
    test_size = int(split * total_size)
    #random_state tham so cho viec tao so ngau nhien va 42 la so thuong duoc dung
    train_x, valid_x = model_selection.train_test_split(images, test_size=valid_size, random_state=42)
    train_y, valid_y = model_selection.train_test_split(masks, test_size=valid_size, random_state=42)

    train_x, test_x = model_selection.train_test_split(train_x, test_size=test_size, random_state=42)
    train_y, test_y = model_selection.train_test_split(train_y, test_size=test_size, random_state=42)
    #print("Tong so anh {}".format(total_size))
    #print("So anh trainning {}".format(len(train_y)))
    #print("So anh dung de danh gia {}".format(len(valid_x)))
    #print("So anh dung de test {}".format(len(test_x)))
    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)

# %%
#Ap dung voi tap val va tap test
#Doc hinh anh sau do chuan hoa
def read_image(path):
    path=path.decode()
    x = cv2.imread(path,cv2.IMREAD_COLOR)
    #Voi dau vao la mot hinh anh mau
    x = cv2.resize(x, (size_unet,size_unet))
    x = x/255.0
    return x

def read_mask(path):
    path=path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (size_unet, size_unet))
    x = x/255.0
    #Them cho du 3 chieu
    x = np.expand_dims ( x, axis = -1)
    return x
#Ham chuyen cac anh ve dang tensorflow
def tf_convert(x, y):
    def _convert(x, y):
      x=read_image(x)
      y=read_mask(y)
      return x,y
    #Chuyen sang dang tensor de dua vao mo hinh
    x, y = tf.numpy_function(_convert, [x, y], [tf.float64, tf.float64])
    #Xac nhan lai hinh dang
    x.set_shape([size_unet, size_unet, 3])
    y.set_shape([size_unet, size_unet, 1])
    return x, y
#Chuan bi de du lieu hoat dong hieu qua voi GPU
#Neu khong co viec chuan bi nay GPU se phai doi CPU load xong du lieu gay ton kem thoi gian
#Cach giai quyet la xu ly song song (pipeline) khi GPU xu ly thi CPU tien hanh chuan bi 
#Dieu nay thuc hien bang cach su dung Tensorflow Dataset API

def tf_dataset(x, y, batch=8):
    #Ham from_tensor_slices() để tạo 1 Dataset objects
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    #Sua lai dung dinh dang ta can thong qua ham tf_convert
    dataset = dataset.map(tf_convert)
    #Chia du lieu theo batch da dinh truoc
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    #Train batch qua nhieu epoch
    dataset = dataset.repeat()
    return dataset

# %%
#Tang cuong du lieu va chuan hoa hinh anh voi cac lop cua Keras
#cac seed tao so ngau nhien phai giong nhau de phu hop giua anh goc va mat na
def Augment(seed=37):
    img = tf.keras.Input(shape=(None,None,3))
    msk = tf.keras.Input(shape=(None,None,1))

    #Lat hinh anh ca tren va duoi
    i = tf.keras.layers.RandomFlip("horizontal",seed=seed)(img)
    m = tf.keras.layers.RandomFlip("horizontal",seed=seed)(msk)
    #Dich vi tri hinh anh mot cach ngau nhien
    i = tf.keras.layers.RandomTranslation((-0.15, 0.15),(-0.15, 0.15),seed=seed)(i)
    m = tf.keras.layers.RandomTranslation((-0.15, 0.15),(-0.15, 0.15),seed=seed)(m)
    #Xoay hinh anh
    i = tf.keras.layers.RandomRotation((-0.15, 0.15),seed=seed)(i)
    m = tf.keras.layers.RandomRotation((-0.15, 0.15),seed=seed)(m)
    #Zoom hinh anh
    i = tf.keras.layers.RandomZoom((-0.1, 0.05),(-0.1, 0.05),seed=seed)(i)
    m = tf.keras.layers.RandomZoom((-0.1, 0.05),(-0.1, 0.05),seed=seed)(m)
    #Chuan hoa lai hinh anh
    i = tf.keras.layers.Rescaling(scale=1./255)(i)
    m = tf.keras.layers.Rescaling(scale=1./255)(m)
    
    return tf.keras.Model(inputs=(img,msk), outputs=(i,m))
Augment = Augment()

# %%
#Ap dung voi tap train
#Doc hinh anh sau do chuan hoa
def read_image_train(path):
    path=path.decode()
    x = cv2.imread(path,cv2.IMREAD_COLOR)
    #Voi dau vao la mot hinh anh mau
    x = cv2.resize(x, (size_unet,size_unet))
    x = x/1.0
    return x

def read_mask_train(path):
    path=path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (size_unet, size_unet))
    x = x/1.0
    #Them cho du 3 chieu
    x = np.expand_dims ( x, axis = -1)
    return x
#Ham chuyen cac anh ve dang tensorflow
def tf_convert_train(x, y):
    def _convert_train(x, y):
      x=read_image_train(x)
      y=read_mask_train(y)
      return x,y
    #Chuyen sang dang tensor de dua vao mo hinh
    x, y = tf.numpy_function(_convert_train, [x, y], [tf.float64, tf.float64])
    #Xac nhan lai hinh dang
    x.set_shape([size_unet, size_unet, 3])
    y.set_shape([size_unet, size_unet, 1])
    return x, y
#Chuan bi de du lieu hoat dong hieu qua voi GPU
#Neu khong co viec chuan bi nay GPU se phai doi CPU load xong du lieu gay ton kem thoi gian
#Cach giai quyet la xu ly song song (pipeline) khi GPU xu ly thi CPU tien hanh chuan bi 
#Dieu nay thuc hien bang cach su dung Tensorflow Dataset API
def tf_dataset_train(x, y, batch=8):
    #Ham from_tensor_slices() để tạo 1 Dataset objects
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    #Sua lai dung dinh dang ta can thong qua ham tf_convert_train
    dataset = dataset.map(tf_convert_train)
    #Chia du lieu theo batch da dinh truoc
    dataset = dataset.batch(batch).map(lambda x,y: Augment((x,y)))
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    #Train batch qua nhieu epoch
    dataset = dataset.repeat()
    return dataset

# %%
#Ham danh gia dice coef
smooth = 1.
def dice_coef(y_true, y_pred):
    y_true_f = tf.keras.layers.Flatten()(y_true)
    y_pred_f = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth)


def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
(train_x,train_y), (valid_x,valid_y),(test_x,test_y)=load_data()

train_dataset = tf_dataset_train(train_x, train_y, batch=batch)
valid_dataset = tf_dataset(valid_x, valid_y, batch=batch)
test_dataset = tf_dataset(test_x, test_y, batch=batch)

# %%
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model 

def squeeze_excite_block(inputs, ratio=8):
    init = inputs
    channel_axis = -1
    filters = init.shape[channel_axis]
    se_shape = (1, 1, filters)

    se = GlobalAveragePooling2D()(init)
    se = Reshape(se_shape)(se)
    se = Dense(filters // ratio, activation='relu', kernel_initializer='he_normal', use_bias=False)(se)
    se = Dense(filters, activation='sigmoid', kernel_initializer='he_normal', use_bias=False)(se)

    x = Multiply()([init, se])
    return x

def stem_block(x, n_filter, strides):
    x_init = x

    ## Conv 1
    x = Conv2D(n_filter, (3, 3), padding="same", strides=strides)(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = Conv2D(n_filter, (3, 3), padding="same")(x)

    ## Shortcut
    s  = Conv2D(n_filter, (1, 1), padding="same", strides=strides)(x_init)
    s = BatchNormalization()(s)

    ## Add
    x = Add()([x, s])
    x = squeeze_excite_block(x)
    return x


def resnet_block(x, n_filter, strides=1):
    x_init = x

    ## Conv 1
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = Conv2D(n_filter, (3, 3), padding="same", strides=strides)(x)
    ## Conv 2
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = Conv2D(n_filter, (3, 3), padding="same", strides=1)(x)

    ## Shortcut
    s  = Conv2D(n_filter, (1, 1), padding="same", strides=strides)(x_init)
    s = BatchNormalization()(s)

    ## Add
    x = Add()([x, s])
    x = squeeze_excite_block(x)
    return x

def aspp_block(x, num_filters, rate_scale=1):
    x1 = Conv2D(num_filters, (3, 3), dilation_rate=(6 * rate_scale, 6 * rate_scale), padding="same")(x)
    x1 = BatchNormalization()(x1)

    x2 = Conv2D(num_filters, (3, 3), dilation_rate=(12 * rate_scale, 12 * rate_scale), padding="same")(x)
    x2 = BatchNormalization()(x2)

    x3 = Conv2D(num_filters, (3, 3), dilation_rate=(18 * rate_scale, 18 * rate_scale), padding="same")(x)
    x3 = BatchNormalization()(x3)

    x4 = Conv2D(num_filters, (3, 3), padding="same")(x)
    x4 = BatchNormalization()(x4)

    y = Add()([x1, x2, x3, x4])
    y = Conv2D(num_filters, (1, 1), padding="same")(y)
    return y

def attetion_block(g, x):
    """
        g: Output of Parallel Encoder block
        x: Output of Previous Decoder block
    """

    filters = x.shape[-1]

    g_conv = BatchNormalization()(g)
    g_conv = Activation("relu")(g_conv)
    g_conv = Conv2D(filters, (3, 3), padding="same")(g_conv)

    g_pool = MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(g_conv)

    x_conv = BatchNormalization()(x)
    x_conv = Activation("relu")(x_conv)
    x_conv = Conv2D(filters, (3, 3), padding="same")(x_conv)

    gc_sum = Add()([g_pool, x_conv])

    gc_conv = BatchNormalization()(gc_sum)
    gc_conv = Activation("relu")(gc_conv)
    gc_conv = Conv2D(filters, (3, 3), padding="same")(gc_conv)

    gc_mul = Multiply()([gc_conv, x])
    return gc_mul

class ResUnetPlusPlus:
    def __init__(self, input_size=256):
        self.input_size = input_size

    def build_model(self):
        n_filters = [64, 128, 256, 512, 1024]
        inputs = Input((self.input_size, self.input_size, 3))

        c0 = inputs
        c1 = stem_block(c0, n_filters[0], strides=1)

        ## Encoder
        c2 = resnet_block(c1, n_filters[1], strides=2)
        c3 = resnet_block(c2, n_filters[2], strides=2)
        c4 = resnet_block(c3, n_filters[3], strides=2)

        ## Bridge
        b1 = aspp_block(c4, n_filters[4])

        ## Decoder
        d1 = attetion_block(c3, b1)
        d1 = UpSampling2D((2, 2))(d1)
        d1 = Concatenate()([d1, c3])
        d1 = resnet_block(d1, n_filters[3])

        d2 = attetion_block(c2, d1)
        d2 = UpSampling2D((2, 2))(d2)
        d2 = Concatenate()([d2, c2])
        d2 = resnet_block(d2, n_filters[2])

        d3 = attetion_block(c1, d2)
        d3 = UpSampling2D((2, 2))(d3)
        d3 = Concatenate()([d3, c1])
        d3 = resnet_block(d3, n_filters[1])

        ## output
        outputs = aspp_block(d3, n_filters[0])
        outputs = Conv2D(1, (1, 1), padding="same")(outputs)
        outputs = Activation("sigmoid")(outputs)

        ## Model
        model = Model(inputs, outputs)
        return model

# %%
arch = ResUnetPlusPlus(input_size=size_unet)
model = arch.build_model()
opt = tf.keras.optimizers.Nadam(lr)
metrics = [Recall(), Precision(), dice_coef, MeanIoU(num_classes=2)]
model.compile(loss=dice_loss, optimizer=opt, metrics=metrics)

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 64  1792        ['input_5[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 256, 256, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 64  256         ['input_5[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 64  256        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  add (Add)                      (None, 256, 256, 64  0           ['conv2d_1[0][0]',
#                                 )                                 'batch_normalization_1[0][0]']
#
#  global_average_pooling2d (Glob  (None, 64)          0           ['add[0][0]']
#  alAveragePooling2D)
#
#  reshape (Reshape)              (None, 1, 1, 64)     0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 1, 1, 8)      512         ['reshape[0][0]']
#
#  dense_1 (Dense)                (None, 1, 1, 64)     512         ['dense[0][0]']
#
#  multiply (Multiply)            (None, 256, 256, 64  0           ['add[0][0]',
#                                 )                                 'dense_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 64  256        ['multiply[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 256, 256, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 12  73856       ['activation_1[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 12  8320        ['multiply[0][0]']
#                                 8)
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 12  512        ['conv2d_5[0][0]']
#  rmalization)                   8)
#
#  add_1 (Add)                    (None, 128, 128, 12  0           ['conv2d_4[0][0]',
#                                 8)                                'batch_normalization_4[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 128)         0           ['add_1[0][0]']
#  obalAveragePooling2D)
#
#  reshape_1 (Reshape)            (None, 1, 1, 128)    0           ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dense_2 (Dense)                (None, 1, 1, 16)     2048        ['reshape_1[0][0]']
#
#  dense_3 (Dense)                (None, 1, 1, 128)    2048        ['dense_2[0][0]']
#
#  multiply_1 (Multiply)          (None, 128, 128, 12  0           ['add_1[0][0]',
#                                 8)                                'dense_3[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 12  512        ['multiply_1[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_5[0][0]']
#                                 8)
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 256)  295168      ['activation_3[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 64, 64, 256)  33024       ['multiply_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 256)  590080      ['activation_4[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_8[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 64, 64, 256)  0           ['conv2d_7[0][0]',
#                                                                   'batch_normalization_7[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 256)         0           ['add_2[0][0]']
#  obalAveragePooling2D)
#
#  reshape_2 (Reshape)            (None, 1, 1, 256)    0           ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
#  dense_4 (Dense)                (None, 1, 1, 32)     8192        ['reshape_2[0][0]']
#
#  dense_5 (Dense)                (None, 1, 1, 256)    8192        ['dense_4[0][0]']
#
#  multiply_2 (Multiply)          (None, 64, 64, 256)  0           ['add_2[0][0]',
#                                                                   'dense_5[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 64, 64, 256)  1024       ['multiply_2[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 512)  1180160     ['activation_5[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 512)  2048       ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 32, 32, 512)  0           ['batch_normalization_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 512)  131584      ['multiply_2[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 32, 32, 512)  0           ['conv2d_10[0][0]',
#                                                                   'batch_normalization_10[0][0]']
#
#  global_average_pooling2d_3 (Gl  (None, 512)         0           ['add_3[0][0]']
#  obalAveragePooling2D)
#
#  reshape_3 (Reshape)            (None, 1, 1, 512)    0           ['global_average_pooling2d_3[0][0
#                                                                  ]']
#
#  dense_6 (Dense)                (None, 1, 1, 64)     32768       ['reshape_3[0][0]']
#
#  dense_7 (Dense)                (None, 1, 1, 512)    32768       ['dense_6[0][0]']
#
#  multiply_3 (Multiply)          (None, 32, 32, 512)  0           ['add_3[0][0]',
#                                                                   'dense_7[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 1024  4719616     ['multiply_3[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 1024  4719616     ['multiply_3[0][0]']
#                                 )
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 1024  4719616     ['multiply_3[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 1024  4719616     ['multiply_3[0][0]']
#                                 )
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 1024  4096       ['conv2d_12[0][0]']
#  ormalization)                  )
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 1024  4096       ['conv2d_13[0][0]']
#  ormalization)                  )
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 1024  4096       ['conv2d_14[0][0]']
#  ormalization)                  )
#
#  batch_normalization_14 (BatchN  (None, 32, 32, 1024  4096       ['conv2d_15[0][0]']
#  ormalization)                  )
#
#  add_4 (Add)                    (None, 32, 32, 1024  0           ['batch_normalization_11[0][0]',
#                                 )                                 'batch_normalization_12[0][0]',
#                                                                   'batch_normalization_13[0][0]',
#                                                                   'batch_normalization_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 64, 64, 256)  1024       ['multiply_2[0][0]']
#  ormalization)
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 1024  1049600     ['add_4[0][0]']
#                                 )
#
#  activation_7 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 32, 32, 1024  4096       ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  conv2d_17 (Conv2D)             (None, 64, 64, 1024  2360320     ['activation_7[0][0]']
#                                 )
#
#  activation_8 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 32, 32, 1024  0           ['conv2d_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  add_5 (Add)                    (None, 32, 32, 1024  0           ['max_pooling2d[0][0]',
#                                 )                                 'conv2d_18[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 1024  4096       ['add_5[0][0]']
#  ormalization)                  )
#
#  activation_9 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 1024  9438208     ['activation_9[0][0]']
#                                 )
#
#  multiply_4 (Multiply)          (None, 32, 32, 1024  0           ['conv2d_19[0][0]',
#                                 )                                 'conv2d_16[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 64, 64, 1024  0           ['multiply_4[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 64, 64, 1280  0           ['up_sampling2d[0][0]',
#                                 )                                 'multiply_2[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 64, 64, 1280  5120       ['concatenate[0][0]']
#  ormalization)                  )
#
#  activation_10 (Activation)     (None, 64, 64, 1280  0           ['batch_normalization_18[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 64, 64, 512)  5898752     ['activation_10[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_19[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 64, 64, 512)  655872      ['concatenate[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_11[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_22[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 64, 64, 512)  0           ['conv2d_21[0][0]',
#                                                                   'batch_normalization_20[0][0]']
#
#  global_average_pooling2d_4 (Gl  (None, 512)         0           ['add_6[0][0]']
#  obalAveragePooling2D)
#
#  reshape_4 (Reshape)            (None, 1, 1, 512)    0           ['global_average_pooling2d_4[0][0
#                                                                  ]']
#
#  dense_8 (Dense)                (None, 1, 1, 64)     32768       ['reshape_4[0][0]']
#
#  dense_9 (Dense)                (None, 1, 1, 512)    32768       ['dense_8[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 128, 128, 12  512        ['multiply_1[0][0]']
#  ormalization)                  8)
#
#  multiply_5 (Multiply)          (None, 64, 64, 512)  0           ['add_6[0][0]',
#                                                                   'dense_9[0][0]']
#
#  activation_12 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_21[0][0]']
#                                 8)
#
#  batch_normalization_22 (BatchN  (None, 64, 64, 512)  2048       ['multiply_5[0][0]']
#  ormalization)
#
#  conv2d_23 (Conv2D)             (None, 128, 128, 51  590336      ['activation_12[0][0]']
#                                 2)
#
#  activation_13 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_22[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 512)  0          ['conv2d_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_13[0][0]']
#
#  add_7 (Add)                    (None, 64, 64, 512)  0           ['max_pooling2d_1[0][0]',
#                                                                   'conv2d_24[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 64, 64, 512)  2048       ['add_7[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_14[0][0]']
#
#  multiply_6 (Multiply)          (None, 64, 64, 512)  0           ['conv2d_25[0][0]',
#                                                                   'multiply_5[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 128, 128, 51  0          ['multiply_6[0][0]']
#                                 2)
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 64  0           ['up_sampling2d_1[0][0]',
#                                 0)                                'multiply_1[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 128, 128, 64  2560       ['concatenate_1[0][0]']
#  ormalization)                  0)
#
#  activation_15 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_24[0][0]']
#                                 0)
#
#  conv2d_26 (Conv2D)             (None, 128, 128, 25  1474816     ['activation_15[0][0]']
#                                 6)
#
#  batch_normalization_25 (BatchN  (None, 128, 128, 25  1024       ['conv2d_26[0][0]']
#  ormalization)                  6)
#
#  activation_16 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_25[0][0]']
#                                 6)
#
#  conv2d_28 (Conv2D)             (None, 128, 128, 25  164096      ['concatenate_1[0][0]']
#                                 6)
#
#  conv2d_27 (Conv2D)             (None, 128, 128, 25  590080      ['activation_16[0][0]']
#                                 6)
#
#  batch_normalization_26 (BatchN  (None, 128, 128, 25  1024       ['conv2d_28[0][0]']
#  ormalization)                  6)
#
#  add_8 (Add)                    (None, 128, 128, 25  0           ['conv2d_27[0][0]',
#                                 6)                                'batch_normalization_26[0][0]']
#
#  global_average_pooling2d_5 (Gl  (None, 256)         0           ['add_8[0][0]']
#  obalAveragePooling2D)
#
#  reshape_5 (Reshape)            (None, 1, 1, 256)    0           ['global_average_pooling2d_5[0][0
#                                                                  ]']
#
#  dense_10 (Dense)               (None, 1, 1, 32)     8192        ['reshape_5[0][0]']
#
#  dense_11 (Dense)               (None, 1, 1, 256)    8192        ['dense_10[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 256, 256, 64  256        ['multiply[0][0]']
#  ormalization)                  )
#
#  multiply_7 (Multiply)          (None, 128, 128, 25  0           ['add_8[0][0]',
#                                 6)                                'dense_11[0][0]']
#
#  activation_17 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_27[0][0]']
#                                 )
#
#  batch_normalization_28 (BatchN  (None, 128, 128, 25  1024       ['multiply_7[0][0]']
#  ormalization)                  6)
#
#  conv2d_29 (Conv2D)             (None, 256, 256, 25  147712      ['activation_17[0][0]']
#                                 6)
#
#  activation_18 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_28[0][0]']
#                                 6)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 128, 128, 25  0          ['conv2d_29[0][0]']
#                                 6)
#
#  conv2d_30 (Conv2D)             (None, 128, 128, 25  590080      ['activation_18[0][0]']
#                                 6)
#
#  add_9 (Add)                    (None, 128, 128, 25  0           ['max_pooling2d_2[0][0]',
#                                 6)                                'conv2d_30[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 128, 128, 25  1024       ['add_9[0][0]']
#  ormalization)                  6)
#
#  activation_19 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_29[0][0]']
#                                 6)
#
#  conv2d_31 (Conv2D)             (None, 128, 128, 25  590080      ['activation_19[0][0]']
#                                 6)
#
#  multiply_8 (Multiply)          (None, 128, 128, 25  0           ['conv2d_31[0][0]',
#                                 6)                                'multiply_7[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 256, 256, 25  0          ['multiply_8[0][0]']
#                                 6)
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 32  0           ['up_sampling2d_2[0][0]',
#                                 0)                                'multiply[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 256, 256, 32  1280       ['concatenate_2[0][0]']
#  ormalization)                  0)
#
#  activation_20 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_30[0][0]']
#                                 0)
#
#  conv2d_32 (Conv2D)             (None, 256, 256, 12  368768      ['activation_20[0][0]']
#                                 8)
#
#  batch_normalization_31 (BatchN  (None, 256, 256, 12  512        ['conv2d_32[0][0]']
#  ormalization)                  8)
#
#  activation_21 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_31[0][0]']
#                                 8)
#
#  conv2d_34 (Conv2D)             (None, 256, 256, 12  41088       ['concatenate_2[0][0]']
#                                 8)
#
#  conv2d_33 (Conv2D)             (None, 256, 256, 12  147584      ['activation_21[0][0]']
#                                 8)
#
#  batch_normalization_32 (BatchN  (None, 256, 256, 12  512        ['conv2d_34[0][0]']
#  ormalization)                  8)
#
#  add_10 (Add)                   (None, 256, 256, 12  0           ['conv2d_33[0][0]',
#                                 8)                                'batch_normalization_32[0][0]']
#
#  global_average_pooling2d_6 (Gl  (None, 128)         0           ['add_10[0][0]']
#  obalAveragePooling2D)
#
#  reshape_6 (Reshape)            (None, 1, 1, 128)    0           ['global_average_pooling2d_6[0][0
#                                                                  ]']
#
#  dense_12 (Dense)               (None, 1, 1, 16)     2048        ['reshape_6[0][0]']
#
#  dense_13 (Dense)               (None, 1, 1, 128)    2048        ['dense_12[0][0]']
#
#  multiply_9 (Multiply)          (None, 256, 256, 12  0           ['add_10[0][0]',
#                                 8)                                'dense_13[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 256, 256, 64  73792       ['multiply_9[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 256, 256, 64  73792       ['multiply_9[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 256, 256, 64  73792       ['multiply_9[0][0]']
#                                 )
#
#  conv2d_38 (Conv2D)             (None, 256, 256, 64  73792       ['multiply_9[0][0]']
#                                 )
#
#  batch_normalization_33 (BatchN  (None, 256, 256, 64  256        ['conv2d_35[0][0]']
#  ormalization)                  )
#
#  batch_normalization_34 (BatchN  (None, 256, 256, 64  256        ['conv2d_36[0][0]']
#  ormalization)                  )
#
#  batch_normalization_35 (BatchN  (None, 256, 256, 64  256        ['conv2d_37[0][0]']
#  ormalization)                  )
#
#  batch_normalization_36 (BatchN  (None, 256, 256, 64  256        ['conv2d_38[0][0]']
#  ormalization)                  )
#
#  add_11 (Add)                   (None, 256, 256, 64  0           ['batch_normalization_33[0][0]',
#                                 )                                 'batch_normalization_34[0][0]',
#                                                                   'batch_normalization_35[0][0]',
#                                                                   'batch_normalization_36[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 256, 256, 64  4160        ['add_11[0][0]']
#                                 )
#
#  conv2d_40 (Conv2D)             (None, 256, 256, 1)  65          ['conv2d_39[0][0]']
#
#  activation_22 (Activation)     (None, 256, 256, 1)  0           ['conv2d_40[0][0]']
#
# ==================================================================================================
# Total params: 64,893,633
# Trainable params: 64,864,065
# Non-trainable params: 29,568
# __________________________________________________________________________________________________

# %%
#Cac tham so ta se quan sat
callbacks = [
          #Luu bo trong so weight    
          ModelCheckpoint("filesr/model.h5"),
          #Theo doi loss function va giam LR
          #factor gia tri learning rate se giam 
          #patience: sau so chu ky ma LR se giam
          ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3),
          #Truyen lai ket qua vao CSV
          CSVLogger("filesr/data.csv"),
          TensorBoard(),
          #Theo doi loss function
          #patience: sau so chu ky neu khong cai thien thi dung
          #restore_best_weights: lua chon khoi phuc tu epoch co ket qua tot nhat
          EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
     ]

# %%
train_steps = len(train_x)//batch
valid_steps = len(valid_x)//batch


if len(train_x) % batch != 0:
        train_steps += 1
if len(valid_x) % batch != 0:
        valid_steps += 1

history=model.fit(train_dataset,
validation_data=valid_dataset,
epochs=epochs,
steps_per_epoch=train_steps,
validation_steps=valid_steps,
callbacks=callbacks,
)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Epoch 1/40
# 100/100 [==============================] - 320s 3s/step - loss: 0.4854 - recall: 0.5778 - precision: 0.4913 - dice_coef: 0.5146 - mean_io_u: 0.5818 - val_loss: 0.6014 - val_recall: 0.3503 - val_precision: 0.4741 - val_dice_coef: 0.3993 - val_mean_io_u: 0.5083 - lr: 1.0000e-04
# Epoch 2/40
# 100/100 [==============================] - 320s 3s/step - loss: 0.4666 - recall: 0.5849 - precision: 0.5140 - dice_coef: 0.5334 - mean_io_u: 0.5922 - val_loss: 0.7310 - val_recall: 0.1578 - val_precision: 0.6689 - val_dice_coef: 0.2648 - val_mean_io_u: 0.4542 - lr: 1.0000e-04
# Epoch 3/40
# 100/100 [==============================] - 311s 3s/step - loss: 0.4528 - recall: 0.5822 - precision: 0.5370 - dice_coef: 0.5472 - mean_io_u: 0.6004 - val_loss: 0.6422 - val_recall: 0.2613 - val_precision: 0.5235 - val_dice_coef: 0.3496 - val_mean_io_u: 0.4985 - lr: 1.0000e-04
# Epoch 4/40
# 100/100 [==============================] - 320s 3s/step - loss: 0.4435 - recall: 0.5842 - precision: 0.5504 - dice_coef: 0.5565 - mean_io_u: 0.6047 - val_loss: 0.5058 - val_recall: 0.4490 - val_precision: 0.5497 - val_dice_coef: 0.4843 - val_mean_io_u: 0.5572 - lr: 1.0000e-04
# Epoch 5/40
# 100/100 [==============================] - 318s 3s/step - loss: 0.4255 - recall: 0.5973 - precision: 0.5737 - dice_coef: 0.5745 - mean_io_u: 0.6180 - val_loss: 0.4426 - val_recall: 0.4883 - val_precision: 0.6381 - val_dice_coef: 0.5497 - val_mean_io_u: 0.5809 - lr: 1.0000e-04
# Epoch 6/40
# 100/100 [==============================] - 321s 3s/step - loss: 0.4202 - recall: 0.5922 - precision: 0.5838 - dice_coef: 0.5798 - mean_io_u: 0.6232 - val_loss: 0.4981 - val_recall: 0.4372 - val_precision: 0.6007 - val_dice_coef: 0.4989 - val_mean_io_u: 0.5689 - lr: 1.0000e-04
# Epoch 7/40
# 100/100 [==============================] - 319s 3s/step - loss: 0.4181 - recall: 0.5875 - precision: 0.5912 - dice_coef: 0.5819 - mean_io_u: 0.6217 - val_loss: 0.4019 - val_recall: 0.7054 - val_precision: 0.5357 - val_dice_coef: 0.5900 - val_mean_io_u: 0.6371 - lr: 1.0000e-04
# Epoch 8/40
# 100/100 [==============================] - 319s 3s/step - loss: 0.4048 - recall: 0.6028 - precision: 0.6029 - dice_coef: 0.5952 - mean_io_u: 0.6321 - val_loss: 0.4197 - val_recall: 0.5672 - val_precision: 0.5988 - val_dice_coef: 0.5806 - val_mean_io_u: 0.6170 - lr: 1.0000e-04
# Epoch 9/40
# 100/100 [==============================] - 312s 3s/step - loss: 0.3983 - recall: 0.6155 - precision: 0.6009 - dice_coef: 0.6017 - mean_io_u: 0.6340 - val_loss: 0.4292 - val_recall: 0.5727 - val_precision: 0.5781 - val_dice_coef: 0.5598 - val_mean_io_u: 0.5984 - lr: 1.0000e-04
# Epoch 10/40
# 100/100 [==============================] - 315s 3s/step - loss: 0.4085 - recall: 0.5949 - precision: 0.5995 - dice_coef: 0.5915 - mean_io_u: 0.6282 - val_loss: 0.4008 - val_recall: 0.6564 - val_precision: 0.5659 - val_dice_coef: 0.5967 - val_mean_io_u: 0.6344 - lr: 1.0000e-04
# Epoch 11/40
# 100/100 [==============================] - 321s 3s/step - loss: 0.3921 - recall: 0.6029 - precision: 0.6215 - dice_coef: 0.6079 - mean_io_u: 0.6406 - val_loss: 0.4471 - val_recall: 0.5362 - val_precision: 0.5753 - val_dice_coef: 0.5565 - val_mean_io_u: 0.5927 - lr: 1.0000e-04
# Epoch 12/40
# 100/100 [==============================] - 314s 3s/step - loss: 0.3832 - recall: 0.5980 - precision: 0.6409 - dice_coef: 0.6168 - mean_io_u: 0.6465 - val_loss: 0.4103 - val_recall: 0.6804 - val_precision: 0.5307 - val_dice_coef: 0.5909 - val_mean_io_u: 0.6364 - lr: 1.0000e-04
# Epoch 13/40
# 100/100 [==============================] - 321s 3s/step - loss: 0.3638 - recall: 0.6187 - precision: 0.6586 - dice_coef: 0.6362 - mean_io_u: 0.6583 - val_loss: 0.4269 - val_recall: 0.6477 - val_precision: 0.5317 - val_dice_coef: 0.5683 - val_mean_io_u: 0.6133 - lr: 1.0000e-04
# Epoch 14/40
# 100/100 [==============================] - 320s 3s/step - loss: 0.3421 - recall: 0.6209 - precision: 0.6963 - dice_coef: 0.6579 - mean_io_u: 0.6723 - val_loss: 0.3633 - val_recall: 0.5867 - val_precision: 0.6915 - val_dice_coef: 0.6337 - val_mean_io_u: 0.6462 - lr: 1.0000e-05
# Epoch 15/40
# 100/100 [==============================] - 321s 3s/step - loss: 0.3281 - recall: 0.6285 - precision: 0.7131 - dice_coef: 0.6719 - mean_io_u: 0.6791 - val_loss: 0.3620 - val_recall: 0.5664 - val_precision: 0.7179 - val_dice_coef: 0.6373 - val_mean_io_u: 0.6461 - lr: 1.0000e-05
# Epoch 16/40
# 100/100 [==============================] - 321s 3s/step - loss: 0.3247 - recall: 0.6276 - precision: 0.7212 - dice_coef: 0.6753 - mean_io_u: 0.6794 - val_loss: 0.3630 - val_recall: 0.5665 - val_precision: 0.7174 - val_dice_coef: 0.6370 - val_mean_io_u: 0.6428 - lr: 1.0000e-05
# Epoch 17/40
# 100/100 [==============================] - 309s 3s/step - loss: 0.3059 - recall: 0.6543 - precision: 0.7299 - dice_coef: 0.6941 - mean_io_u: 0.6937 - val_loss: 0.3507 - val_recall: 0.5817 - val_precision: 0.7241 - val_dice_coef: 0.6481 - val_mean_io_u: 0.6526 - lr: 1.0000e-05
# Epoch 18/40
# 100/100 [==============================] - 321s 3s/step - loss: 0.3051 - recall: 0.6517 - precision: 0.7364 - dice_coef: 0.6949 - mean_io_u: 0.6939 - val_loss: 0.3465 - val_recall: 0.5758 - val_precision: 0.7392 - val_dice_coef: 0.6526 - val_mean_io_u: 0.6533 - lr: 1.0000e-05
# Epoch 19/40
# 100/100 [==============================] - 325s 3s/step - loss: 0.2968 - recall: 0.6558 - precision: 0.7464 - dice_coef: 0.7032 - mean_io_u: 0.6978 - val_loss: 0.3473 - val_recall: 0.5805 - val_precision: 0.7330 - val_dice_coef: 0.6520 - val_mean_io_u: 0.6524 - lr: 1.0000e-05
# Epoch 20/40
# 100/100 [==============================] - 313s 3s/step - loss: 0.2989 - recall: 0.6489 - precision: 0.7476 - dice_coef: 0.7011 - mean_io_u: 0.6966 - val_loss: 0.3607 - val_recall: 0.5696 - val_precision: 0.7154 - val_dice_coef: 0.6392 - val_mean_io_u: 0.6441 - lr: 1.0000e-05
# Epoch 21/40
# 100/100 [==============================] - 317s 3s/step - loss: 0.2910 - recall: 0.6574 - precision: 0.7587 - dice_coef: 0.7090 - mean_io_u: 0.7011 - val_loss: 0.3794 - val_recall: 0.5113 - val_precision: 0.7480 - val_dice_coef: 0.6209 - val_mean_io_u: 0.6234 - lr: 1.0000e-05
# Epoch 22/40
# 100/100 [==============================] - 312s 3s/step - loss: 0.2803 - recall: 0.6576 - precision: 0.7771 - dice_coef: 0.7197 - mean_io_u: 0.7067 - val_loss: 0.3582 - val_recall: 0.5611 - val_precision: 0.7233 - val_dice_coef: 0.6422 - val_mean_io_u: 0.6365 - lr: 1.0000e-06
# Epoch 23/40
# 100/100 [==============================] - 308s 3s/step - loss: 0.2840 - recall: 0.6557 - precision: 0.7696 - dice_coef: 0.7160 - mean_io_u: 0.7012 - val_loss: 0.3476 - val_recall: 0.5919 - val_precision: 0.7099 - val_dice_coef: 0.6526 - val_mean_io_u: 0.6459 - lr: 1.0000e-06
# Epoch 24/40
# 100/100 [==============================] - 308s 3s/step - loss: 0.2730 - recall: 0.6715 - precision: 0.7771 - dice_coef: 0.7270 - mean_io_u: 0.7118 - val_loss: 0.3458 - val_recall: 0.5975 - val_precision: 0.7067 - val_dice_coef: 0.6543 - val_mean_io_u: 0.6481 - lr: 1.0000e-06
# Epoch 25/40
# 100/100 [==============================] - 306s 3s/step - loss: 0.2823 - recall: 0.6586 - precision: 0.7709 - dice_coef: 0.7177 - mean_io_u: 0.7029 - val_loss: 0.3469 - val_recall: 0.5959 - val_precision: 0.7060 - val_dice_coef: 0.6536 - val_mean_io_u: 0.6490 - lr: 1.0000e-06
# Epoch 26/40
# 100/100 [==============================] - 301s 3s/step - loss: 0.2786 - recall: 0.6608 - precision: 0.7738 - dice_coef: 0.7214 - mean_io_u: 0.7051 - val_loss: 0.3490 - val_recall: 0.5942 - val_precision: 0.7015 - val_dice_coef: 0.6514 - val_mean_io_u: 0.6472 - lr: 1.0000e-06
# Epoch 27/40
# 100/100 [==============================] - 309s 3s/step - loss: 0.2753 - recall: 0.6636 - precision: 0.7782 - dice_coef: 0.7247 - mean_io_u: 0.7080 - val_loss: 0.3500 - val_recall: 0.5942 - val_precision: 0.6997 - val_dice_coef: 0.6506 - val_mean_io_u: 0.6465 - lr: 1.0000e-06
# Epoch 28/40
# 100/100 [==============================] - 306s 3s/step - loss: 0.2804 - recall: 0.6561 - precision: 0.7776 - dice_coef: 0.7196 - mean_io_u: 0.7053 - val_loss: 0.3495 - val_recall: 0.5982 - val_precision: 0.6960 - val_dice_coef: 0.6512 - val_mean_io_u: 0.6486 - lr: 1.0000e-07
# Epoch 29/40
# 100/100 [==============================] - 318s 3s/step - loss: 0.2826 - recall: 0.6573 - precision: 0.7716 - dice_coef: 0.7174 - mean_io_u: 0.7051 - val_loss: 0.3492 - val_recall: 0.5985 - val_precision: 0.6960 - val_dice_coef: 0.6514 - val_mean_io_u: 0.6491 - lr: 1.0000e-07
# Epoch 30/40
# 100/100 [==============================] - 293s 3s/step - loss: 0.2728 - recall: 0.6623 - precision: 0.7827 - dice_coef: 0.7272 - mean_io_u: 0.7090 - val_loss: 0.3491 - val_recall: 0.5983 - val_precision: 0.6970 - val_dice_coef: 0.6516 - val_mean_io_u: 0.6485 - lr: 1.0000e-07
# Epoch 31/40
# 100/100 [==============================] - 307s 3s/step - loss: 0.2831 - recall: 0.6580 - precision: 0.7698 - dice_coef: 0.7169 - mean_io_u: 0.7019 - val_loss: 0.3500 - val_recall: 0.6031 - val_precision: 0.6895 - val_dice_coef: 0.6508 - val_mean_io_u: 0.6495 - lr: 1.0000e-08
# Epoch 32/40
# 100/100 [==============================] - 320s 3s/step - loss: 0.2785 - recall: 0.6623 - precision: 0.7727 - dice_coef: 0.7215 - mean_io_u: 0.7079 - val_loss: 0.3506 - val_recall: 0.5949 - val_precision: 0.6972 - val_dice_coef: 0.6501 - val_mean_io_u: 0.6474 - lr: 1.0000e-08
# Epoch 33/40
# 100/100 [==============================] - 321s 3s/step - loss: 0.2763 - recall: 0.6670 - precision: 0.7746 - dice_coef: 0.7237 - mean_io_u: 0.7100 - val_loss: 0.3492 - val_recall: 0.5997 - val_precision: 0.6947 - val_dice_coef: 0.6514 - val_mean_io_u: 0.6487 - lr: 1.0000e-08
# Epoch 34/40
# 100/100 [==============================] - 320s 3s/step - loss: 0.2764 - recall: 0.6625 - precision: 0.7781 - dice_coef: 0.7236 - mean_io_u: 0.7099 - val_loss: 0.3493 - val_recall: 0.5985 - val_precision: 0.6959 - val_dice_coef: 0.6512 - val_mean_io_u: 0.6490 - lr: 1.0000e-09

# %%
print(history.history.keys())
# summarize history for dice_coef
plt.plot(history.history['dice_coef'])
plt.plot(history.history['val_dice_coef'])
plt.title('Ket qua dice_coef')
plt.ylabel('dice_coef')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for accuracy
plt.plot(history.history['mean_io_u'])
plt.plot(history.history['val_mean_io_u'])
plt.title('Ket qua mean_io_u')
plt.ylabel('mean_io_u')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Ket qua loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'recall', 'precision', 'dice_coef', 'mean_io_u', 'val_loss', 'val_recall', 'val_precision', 'val_dice_coef', 'val_mean_io_u', 'lr'])

# %%
test_steps = (len(test_x)//batch)
if len(test_x) % batch != 0:
  test_steps += 1
with CustomObjectScope({'dice_loss': dice_loss, 'dice_coef': dice_coef}):
  model = tf.keras.models.load_model("filesr/model.h5")
model.evaluate(test_dataset, steps=test_steps)
# Out:
# 13/13 [==============================] - 28s 2s/step - loss: 0.3347 - recall: 0.5971 - precision: 0.7410 - dice_coef: 0.6664 - mean_io_u: 0.6549
# [0.33466270565986633,
#  0.5971142053604126,
#  0.7409806251525879,
#  0.6664219498634338,
#  0.6549040079116821]

# %%
def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (256, 256))
    x = x/255.0
    return x

def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (256, 256))
    x = np.expand_dims(x, axis=-1)
    return x

def mask_parse(mask):
    mask = np.squeeze(mask)
    mask = [mask, mask, mask]
    mask = np.transpose(mask, (1, 2, 0))
    return mask

# %%
for i, (x, y) in tqdm(enumerate(zip(test_x, test_y)), total=len(test_x)):
        x = read_image(x)
        y = read_mask(y)
        y_pred = model.predict(np.expand_dims(x, axis=0))[0] > 0.5
        h, w, _ = x.shape
        white_line = np.ones((h, 10, 3)) * 255.0

        all_images = [
            x * 255.0, white_line,
            mask_parse(y), white_line,
            mask_parse(y_pred) * 255.0
        ]
        image = np.concatenate(all_images, axis=1)
        cv2.imwrite(f"resultsr/{i}.png", image)
# Out:
# 100%|██████████| 100/100 [00:25<00:00,  3.87it/s]
